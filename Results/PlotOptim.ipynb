# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/ARC_heuristic/PlotsPaper/')
print(os.getcwd())
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1b0U2fABpE8D898NvKTrvvqqusm1peAQH/ARC_heuristic/PlotsPaper

# %%
import numpy as np
import pylab as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from matplotlib.legend_handler import HandlerTuple

import matplotlib as mpl


mpl.rcParams.update({'text.usetex':True,'font.size': 12, 'font.family': 'serif', 
                    'font.serif': ['Times', 'Computer Modern'],
                    'text.latex.preamble':r'\usepackage{bm}'})


color = ['tab:red','tab:blue','tab:purple','tab:orange']

path = 'Data_QNN/logLossMN/optimized/ACC_test'

orgFile = path+'.txt'
optFile = path+'_optimized_bfgs.txt'
optFilec = path+'_optimized_cobyla.txt'

optFilecr_5 = []
for i in range(1,11):
    optFilecr_5.append(path+f'_optimized_cobyla_rndInitAngle_5gate_{i}.txt')
optFilecr_10 = []
for i in range(1,11):
    optFilecr_10.append(path+f'_optimized_cobyla_rndInitAngle_10gate_{i}.txt')
optFilecr_15 = []
for i in range(1,11):
    optFilecr_15.append(path+f'_optimized_cobyla_rndInitAngle_15gate_{i}.txt')
optFilecr_20 = []
for i in range(1,11):
    optFilecr_20.append(path+f'_optimized_cobyla_rndInitAngle_20gate_{i}.txt')
optFilecr_25 = []
for i in range(1,11):
    optFilecr_25.append(path+f'_optimized_cobyla_rndInitAngle_25gate_{i}.txt')
optFilecr_30 = []
for i in range(1,11):
    optFilecr_30.append(path+f'_optimized_cobyla_rndInitAngle_30gate_{i}.txt')
optFilecr_35 = []
for i in range(1,11):
    optFilecr_35.append(path+f'_optimized_cobyla_rndInitAngle_35gate_{i}.txt')
optFilecr_40 = []
for i in range(1,11):
    optFilecr_40.append(path+f'_optimized_cobyla_rndInitAngle_40gate_{i}.txt')

optFilebr = path+'_optimized_bfgs_rndInitAngle_1.txt'
optFilebr2 = path+'_optimized_bfgs_rndInitAngle_2.txt'
optFilebr3 = path+'_optimized_bfgs_rndInitAngle_3.txt'


optFilebr_5 = []
for i in range(1,11):
    optFilebr_5.append(path+f'_optimized_bfgs_rndInitAngle_5gate_{i}.txt')
optFilebr_10 = []
for i in range(1,11):
    optFilebr_10.append(path+f'_optimized_bfgs_rndInitAngle_10gate_{i}.txt')
optFilebr_15 = []
for i in range(1,11):
    optFilebr_15.append(path+f'_optimized_bfgs_rndInitAngle_15gate_{i}.txt')
optFilebr_20 = []
for i in range(1,11):
    optFilebr_20.append(path+f'_optimized_bfgs_rndInitAngle_20gate_{i}.txt')
optFilebr_25 = []
for i in range(1,11):
    optFilebr_25.append(path+f'_optimized_bfgs_rndInitAngle_25gate_{i}.txt')
optFilebr_30 = []
for i in range(1,11):
    optFilebr_30.append(path+f'_optimized_bfgs_rndInitAngle_30gate_{i}.txt')
optFilebr_35 = []
for i in range(1,11):
    optFilebr_35.append(path+f'_optimized_bfgs_rndInitAngle_35gate_{i}.txt')
optFilebr_40 = []
for i in range(1,11):
    optFilebr_40.append(path+f'_optimized_bfgs_rndInitAngle_40gate_{i}.txt')



def readin(infile):
	Acc0 = np.genfromtxt(infile,usecols=0,skip_header=1)
	Acc1 = np.genfromtxt(infile,usecols=1,skip_header=1)
	Acc0 = np.array([0.5,*Acc0])
	Acc1 = np.array([0.5,*Acc1])
	AccAver = (Acc0+Acc1)*0.5

	return AccAver


AccAver_org = readin(orgFile)
AccAver_opt = readin(optFile)
AccAver_optc = readin(optFilec)

AccAver_optcr_5=[]
for i in range(0,10):
    AccAver_optcr_5.append(readin(optFilecr_5[i])[-1])
AccAver_optcr_10=[]
for i in range(0,10):
    AccAver_optcr_10.append(readin(optFilecr_10[i])[-1])
AccAver_optcr_15=[]
for i in range(0,10):
    AccAver_optcr_15.append(readin(optFilecr_15[i])[-1])
AccAver_optcr_20=[]
for i in range(0,10):
    AccAver_optcr_20.append(readin(optFilecr_20[i])[-1])
AccAver_optcr_25=[]
for i in range(0,10):
    AccAver_optcr_25.append(readin(optFilecr_25[i])[-1])
AccAver_optcr_30=[]
for i in range(0,10):
    AccAver_optcr_30.append(readin(optFilecr_30[i])[-1])
AccAver_optcr_35=[]
for i in range(0,10):
    AccAver_optcr_35.append(readin(optFilecr_35[i])[-1])
AccAver_optcr_40=[]
for i in range(0,10):
	if i!=0:
		AccAver_optcr_40.append(readin(optFilecr_40[i])[-1])

AccAver_optbr_5=[]
for i in range(0,10):
    AccAver_optbr_5.append(readin(optFilebr_5[i])[-1])
AccAver_optbr_10=[]
for i in range(0,10):
    AccAver_optbr_10.append(readin(optFilebr_10[i])[-1])
AccAver_optbr_15=[]
for i in range(0,10):
	if i!=1:
		AccAver_optbr_15.append(readin(optFilebr_15[i])[-1])
AccAver_optbr_20=[]
for i in range(0,10):
    AccAver_optbr_20.append(readin(optFilebr_20[i])[-1])
AccAver_optbr_25=[]
for i in range(0,10):
	if i!=3:
		AccAver_optbr_25.append(readin(optFilebr_25[i])[-1])
AccAver_optbr_30=[]
for i in range(0,10):
    AccAver_optbr_30.append(readin(optFilebr_30[i])[-1])
AccAver_optbr_35=[]
for i in range(0,10):
	AccAver_optbr_35.append(readin(optFilebr_35[i])[-1])
AccAver_optbr_40=[]
for i in range(0,10):
	if i!=0:
		AccAver_optbr_40.append(readin(optFilebr_40[i])[-1])


mean_optcr_5 = 1/len(AccAver_optcr_5)*sum(AccAver_optcr_5)
vari_optcr_5 = 1/9*np.sqrt((mean_optcr_5-AccAver_optcr_5[0])**2+
	(mean_optcr_5-AccAver_optcr_5[1])**2+(mean_optcr_5-AccAver_optcr_5[2])**2+
	(mean_optcr_5-AccAver_optcr_5[3])**2+(mean_optcr_5-AccAver_optcr_5[4])**2+
	(mean_optcr_5-AccAver_optcr_5[5])**2+(mean_optcr_5-AccAver_optcr_5[6])**2+
	(mean_optcr_5-AccAver_optcr_5[7])**2+(mean_optcr_5-AccAver_optcr_5[8])**2+
	(mean_optcr_5-AccAver_optcr_5[9])**2)
mean_optcr_10 = 1/len(AccAver_optcr_10)*sum(AccAver_optcr_10)
vari_optcr_10 = 1/9*np.sqrt((mean_optcr_10-AccAver_optcr_10[0])**2+
	(mean_optcr_10-AccAver_optcr_10[1])**2+(mean_optcr_10-AccAver_optcr_10[2])**2+
	(mean_optcr_10-AccAver_optcr_10[3])**2+(mean_optcr_10-AccAver_optcr_10[4])**2+
	(mean_optcr_10-AccAver_optcr_10[5])**2+(mean_optcr_10-AccAver_optcr_10[6])**2+
	(mean_optcr_10-AccAver_optcr_10[7])**2+(mean_optcr_10-AccAver_optcr_10[8])**2+
	(mean_optcr_10-AccAver_optcr_10[9])**2)
mean_optcr_15 = 1/len(AccAver_optcr_15)*sum(AccAver_optcr_15)
vari_optcr_15 = 1/9*np.sqrt((mean_optcr_15-AccAver_optcr_15[0])**2+
	(mean_optcr_15-AccAver_optcr_15[1])**2+(mean_optcr_15-AccAver_optcr_15[2])**2+
	(mean_optcr_15-AccAver_optcr_15[3])**2+(mean_optcr_15-AccAver_optcr_15[4])**2+
	(mean_optcr_15-AccAver_optcr_15[5])**2+(mean_optcr_15-AccAver_optcr_15[6])**2+
	(mean_optcr_15-AccAver_optcr_15[7])**2+(mean_optcr_15-AccAver_optcr_15[8])**2+
	(mean_optcr_15-AccAver_optcr_15[9])**2)
print(AccAver_optcr_20)
mean_optcr_20 = 1/len(AccAver_optcr_20)*sum(AccAver_optcr_20)
vari_optcr_20 = 1/9*np.sqrt((mean_optcr_20-AccAver_optcr_20[0])**2+
	(mean_optcr_20-AccAver_optcr_20[1])**2+(mean_optcr_20-AccAver_optcr_20[2])**2+
	(mean_optcr_20-AccAver_optcr_20[3])**2+(mean_optcr_20-AccAver_optcr_20[4])**2+
	(mean_optcr_20-AccAver_optcr_20[5])**2+(mean_optcr_20-AccAver_optcr_20[6])**2+
	(mean_optcr_20-AccAver_optcr_20[7])**2+(mean_optcr_20-AccAver_optcr_20[8])**2+
    (mean_optcr_20-AccAver_optcr_20[9])**2)
mean_optcr_25 = 1/len(AccAver_optcr_25)*sum(AccAver_optcr_25)
vari_optcr_25 = 1/9*np.sqrt((mean_optcr_25-AccAver_optcr_25[0])**2+
	(mean_optcr_25-AccAver_optcr_25[1])**2+(mean_optcr_25-AccAver_optcr_25[2])**2+
	(mean_optcr_25-AccAver_optcr_25[3])**2+(mean_optcr_25-AccAver_optcr_25[4])**2+
	(mean_optcr_25-AccAver_optcr_25[5])**2+(mean_optcr_25-AccAver_optcr_25[6])**2+
	(mean_optcr_25-AccAver_optcr_25[7])**2+(mean_optcr_25-AccAver_optcr_25[8])**2+
	(mean_optcr_25-AccAver_optcr_25[9])**2)
mean_optcr_30 = 1/len(AccAver_optcr_30)*sum(AccAver_optcr_30)
vari_optcr_30 = 1/9*np.sqrt((mean_optcr_30-AccAver_optcr_30[0])**2+
	(mean_optcr_30-AccAver_optcr_30[1])**2+(mean_optcr_30-AccAver_optcr_30[2])**2+
	(mean_optcr_30-AccAver_optcr_30[3])**2+(mean_optcr_30-AccAver_optcr_30[4])**2+
	(mean_optcr_30-AccAver_optcr_30[5])**2+(mean_optcr_30-AccAver_optcr_30[6])**2+
	(mean_optcr_30-AccAver_optcr_30[7])**2+(mean_optcr_30-AccAver_optcr_30[8])**2+
    (mean_optcr_30-AccAver_optcr_30[9])**2)
mean_optcr_35 = 1/len(AccAver_optcr_35)*sum(AccAver_optcr_35)
vari_optcr_35 = 1/9*np.sqrt((mean_optcr_35-AccAver_optcr_35[0])**2+
	(mean_optcr_35-AccAver_optcr_35[1])**2+(mean_optcr_35-AccAver_optcr_35[2])**2+
	(mean_optcr_35-AccAver_optcr_35[3])**2+(mean_optcr_35-AccAver_optcr_35[4])**2+
	(mean_optcr_35-AccAver_optcr_35[5])**2+(mean_optcr_35-AccAver_optcr_35[6])**2+
	(mean_optcr_35-AccAver_optcr_35[7])**2+(mean_optcr_35-AccAver_optcr_35[8])**2+
    (mean_optcr_35-AccAver_optcr_35[9])**2)
mean_optcr_40 = 1/len(AccAver_optcr_40)*sum(AccAver_optcr_40)
vari_optcr_40 = 1/8*np.sqrt((mean_optcr_40-AccAver_optcr_40[0])**2+
	(mean_optcr_40-AccAver_optcr_40[1])**2+(mean_optcr_40-AccAver_optcr_40[2])**2+
	(mean_optcr_40-AccAver_optcr_40[3])**2+(mean_optcr_40-AccAver_optcr_40[4])**2+
	(mean_optcr_40-AccAver_optcr_40[5])**2+(mean_optcr_40-AccAver_optcr_40[6])**2+
	(mean_optcr_40-AccAver_optcr_40[7])**2+(mean_optcr_40-AccAver_optcr_40[8])**2)

mean_optbr_5 = 1/len(AccAver_optbr_5)*sum(AccAver_optbr_5)
vari_optbr_5 = 1/9*np.sqrt((mean_optbr_5-AccAver_optbr_5[0])**2+
	(mean_optbr_5-AccAver_optbr_5[1])**2+	(mean_optbr_5-AccAver_optbr_5[2])**2+
	(mean_optbr_5-AccAver_optbr_5[3])**2+	(mean_optbr_5-AccAver_optbr_5[4])**2+
	(mean_optbr_5-AccAver_optbr_5[5])**2+	(mean_optbr_5-AccAver_optbr_5[6])**2+
	(mean_optbr_5-AccAver_optbr_5[7])**2+	(mean_optbr_5-AccAver_optbr_5[8])**2+
	(mean_optbr_5-AccAver_optbr_5[9])**2)
mean_optbr_10 = 1/len(AccAver_optbr_10)*sum(AccAver_optbr_10)
vari_optbr_10 = 1/9*np.sqrt((mean_optbr_10-AccAver_optbr_10[0])**2+
	(mean_optbr_10-AccAver_optbr_10[1])**2+	(mean_optbr_10-AccAver_optbr_10[2])**2+
	(mean_optbr_10-AccAver_optbr_10[3])**2+	(mean_optbr_10-AccAver_optbr_10[4])**2+
	(mean_optbr_10-AccAver_optbr_10[5])**2+	(mean_optbr_10-AccAver_optbr_10[6])**2+
	(mean_optbr_10-AccAver_optbr_10[7])**2+	(mean_optbr_10-AccAver_optbr_10[8])**2+
	(mean_optbr_10-AccAver_optbr_10[9])**2)
mean_optbr_15 = 1/len(AccAver_optbr_15)*sum(AccAver_optbr_15)
vari_optbr_15 = 1/9*np.sqrt((mean_optbr_15-AccAver_optbr_15[0])**2+
	(mean_optbr_15-AccAver_optbr_15[1])**2+	(mean_optbr_15-AccAver_optbr_15[2])**2+
	(mean_optbr_15-AccAver_optbr_15[3])**2+	(mean_optbr_15-AccAver_optbr_15[4])**2+
	(mean_optbr_15-AccAver_optbr_15[5])**2+	(mean_optbr_15-AccAver_optbr_15[6])**2+
	(mean_optbr_15-AccAver_optbr_15[7])**2+	(mean_optbr_15-AccAver_optbr_15[8])**2+
	(mean_optbr_15-AccAver_optbr_15[0])**2)
mean_optbr_20 = 1/len(AccAver_optbr_20)*sum(AccAver_optbr_20)
vari_optbr_20 = 1/9*np.sqrt((mean_optbr_20-AccAver_optbr_20[0])**2+
	(mean_optbr_20-AccAver_optbr_20[1])**2+	(mean_optbr_20-AccAver_optbr_20[2])**2+
	(mean_optbr_20-AccAver_optbr_20[3])**2+	(mean_optbr_20-AccAver_optbr_20[4])**2+
	(mean_optbr_20-AccAver_optbr_20[5])**2+	(mean_optbr_20-AccAver_optbr_20[6])**2+
	(mean_optbr_20-AccAver_optbr_20[7])**2+	(mean_optbr_20-AccAver_optbr_20[8])**2+
	(mean_optbr_20-AccAver_optbr_20[9])**2)
mean_optbr_25 = 1/len(AccAver_optbr_25)*sum(AccAver_optbr_25)
vari_optbr_25 = 1/8*np.sqrt((mean_optbr_25-AccAver_optbr_25[0])**2+
	(mean_optbr_25-AccAver_optbr_25[1])**2+	(mean_optbr_25-AccAver_optbr_25[2])**2+
	(mean_optbr_25-AccAver_optbr_25[3])**2+	(mean_optbr_25-AccAver_optbr_25[4])**2+
	(mean_optbr_25-AccAver_optbr_25[5])**2+	(mean_optbr_25-AccAver_optbr_25[6])**2+
	(mean_optbr_25-AccAver_optbr_25[7])**2+	(mean_optbr_25-AccAver_optbr_25[8])**2)
mean_optbr_30 = 1/len(AccAver_optbr_30)*sum(AccAver_optbr_30)
vari_optbr_30 = 1/9*np.sqrt((mean_optbr_30-AccAver_optbr_30[0])**2+
	(mean_optbr_30-AccAver_optbr_30[1])**2+	(mean_optbr_30-AccAver_optbr_30[2])**2+
	(mean_optbr_30-AccAver_optbr_30[3])**2+	(mean_optbr_30-AccAver_optbr_30[4])**2+
	(mean_optbr_30-AccAver_optbr_30[5])**2+	(mean_optbr_30-AccAver_optbr_30[6])**2+
	(mean_optbr_30-AccAver_optbr_30[7])**2+	(mean_optbr_30-AccAver_optbr_30[8])**2+
	(mean_optbr_30-AccAver_optbr_30[9])**2)
mean_optbr_35 = 1/len(AccAver_optbr_35)*sum(AccAver_optbr_35)
vari_optbr_35 = 1/9*np.sqrt((mean_optbr_35-AccAver_optbr_35[0])**2+
    (mean_optbr_35-AccAver_optbr_35[1])**2+(mean_optbr_35-AccAver_optbr_35[2])**2+
    (mean_optbr_35-AccAver_optbr_35[3])**2+(mean_optbr_35-AccAver_optbr_35[4])**2+
    (mean_optbr_35-AccAver_optbr_35[5])**2+(mean_optbr_35-AccAver_optbr_35[6])**2+
    (mean_optbr_35-AccAver_optbr_35[7])**2+(mean_optbr_35-AccAver_optbr_35[8])**2+
    (mean_optbr_35-AccAver_optbr_35[9])**2)
mean_optbr_40 = 1/len(AccAver_optbr_40)*sum(AccAver_optbr_40)
vari_optbr_40 = 1/8*np.sqrt((mean_optbr_40-AccAver_optbr_40[0])**2+
	(mean_optbr_40-AccAver_optbr_40[1])**2+(mean_optbr_40-AccAver_optbr_40[2])**2+
	(mean_optbr_40-AccAver_optbr_40[3])**2+(mean_optbr_40-AccAver_optbr_40[4])**2+
	(mean_optbr_40-AccAver_optbr_40[5])**2+(mean_optbr_40-AccAver_optbr_40[6])**2+
	(mean_optbr_40-AccAver_optbr_40[7])**2+(mean_optbr_40-AccAver_optbr_40[8])**2)


gates = np.linspace(0,len(AccAver_org)-1,len(AccAver_org))
gates_opt = np.linspace(0,len(AccAver_opt)-1,len(AccAver_opt))
gates_optc = np.linspace(0,len(AccAver_optc)-1,len(AccAver_optc))


fig, ax1 = plt.subplots(1,1,sharex=True,figsize=(11.69*0.4,8.27*0.38))

a1,=ax1.plot(gates,AccAver_org*100,'-',color=color[2],label='Q-FLAIR',zorder=4)
a2,=ax1.plot(gates_opt,AccAver_opt*100,'+',color='violet',label='L-BFGS-B',zorder=1)
a3,=ax1.plot(gates_optc,AccAver_optc*100,'x',color='blueviolet',label='COBYLA',fillstyle='none',zorder=2)

a41=ax1.errorbar([5,10,15,20,25,30,35,40],
	[mean_optbr_5*100,mean_optbr_10*100,mean_optbr_15*100,mean_optbr_20*100,
	mean_optbr_25*100,mean_optbr_30*100,mean_optbr_35*100,mean_optbr_40*100],
	[vari_optbr_5*100,vari_optbr_10*100,vari_optbr_15*100,vari_optbr_20*100,
	vari_optbr_25*100,vari_optbr_30*100,vari_optbr_35*100,vari_optbr_40*100],
	fmt='d',color='darkmagenta',
	label=r'L-BFGS-B, rand. $\bm{\theta}_0$',zorder=4,fillstyle='none')
a4=ax1.errorbar([5,10,15,20,25,30,35,40],
	[mean_optcr_5*100,mean_optcr_10*100,mean_optcr_15*100,mean_optcr_20*100
	,mean_optcr_25*100,mean_optcr_30*100,mean_optcr_35*100,mean_optcr_40*100],
	[vari_optcr_5*100,vari_optcr_10*100,vari_optcr_15*100,vari_optcr_20*100
	,vari_optcr_25*100,vari_optcr_30*100,vari_optcr_35*100,vari_optcr_40*100],
	fmt='s',color='deeppink',
	label=r'COBYLA, rand. $\bm{\theta}_0$',zorder=3,fillstyle='none')


ax1.set_xlim(0,55)#len(gates))

symbol = ['+','x','s']


ax1.set_ylim(0.3*100,1*100)
ax1.set_xlabel('number of gates',fontsize='medium')
ax1.set_ylabel(r'accuracy [\%]',fontsize='medium')


ax1.legend(ncol=2,fontsize='small')

fig.tight_layout()
fig.savefig('Acc_Optimized_paper.pdf')
plt.show()
# Out:
# [0.8111230741908271, 0.9188429605292368, 0.8273997691248945, 0.7243628735070816, 0.8078231141499801, 0.6818718643164765, 0.9128657372463704, 0.9001409670114994, 0.9172845535674643, 0.8971418105936154]
